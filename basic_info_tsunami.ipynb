# %%
import pandas as pd

# loading the tsunami historical runups datasets
df = pd.read_csv("historical_runups.csv")

# %%
df.shape
# Out:
# (28195, 34)

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28195 entries, 0 to 28194
# Data columns (total 34 columns):
# id                              28195 non-null int64
# tsevent_id                      28195 non-null int64
# year                            28195 non-null int64
# month                           28083 non-null float64
# day                             27966 non-null float64
# timestamp                       27966 non-null object
# doubtful                        500 non-null object
# country                         28193 non-null object
# state                           22477 non-null object
# location_name                   28190 non-null object
# latitude                        27555 non-null float64
# longitude                       27555 non-null float64
# region_code                     28195 non-null int64
# distance_from_source            27236 non-null float64
# arr_day                         3705 non-null float64
# ...

# %%
df.describe()
# Out:
#                  id    tsevent_id          year         month           day  \
# count  28195.000000  28195.000000  28195.000000  28083.000000  27966.000000
# mean   17892.847810   3239.207838   1961.331513      6.242994     15.522098
# std     9687.838748   1755.437520    133.655547      3.547795      8.572706
# min        1.000000      1.000000  -2000.000000      1.000000      1.000000
# 25%    10338.500000   1902.000000   1956.000000      3.000000     11.000000
# 50%    18352.000000   2439.000000   2001.000000      5.000000     13.000000
# 75%    25514.500000   5413.000000   2011.000000      9.000000     23.000000
# max    34549.000000   5753.000000   2020.000000     12.000000     31.000000
#
#            latitude     longitude   region_code  distance_from_source  \
# count  27555.000000  27555.000000  28195.000000          27236.000000
# mean      20.741582     51.509464     80.293421           2401.912542
# std       25.347971    119.799477     10.128054           4171.898917
# ...

# %%
df.dtypes
# Out:
# id                                int64
# tsevent_id                        int64
# year                              int64
# month                           float64
# day                             float64
# timestamp                        object
# doubtful                         object
# country                          object
# state                            object
# location_name                    object
# latitude                        float64
# longitude                       float64
# region_code                       int64
# distance_from_source            float64
# arr_day                         float64
# arr_hour                        float64
# arr_min                         float64
# travel_time_hours               float64
# travel_time_minutes             float64
# water_ht                        float64
# horizontal_inundation           float64
# type_measurement_id             float64
# period                          float64
# ...

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EEB7ECA048>,
# ...
#       dtype=object)

# %%
# loading the tsunami historical source event datasets
df = pd.read_csv("historical_source_event.csv")

# %%
df.shape
# Out:
# (2691, 44)

# %%
df.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2691 entries, 0 to 2690
# Data columns (total 44 columns):
# id                                    2691 non-null int64
# year                                  2691 non-null int64
# month                                 2543 non-null float64
# day                                   2436 non-null float64
# timestamp                             2434 non-null object
# event_validity                        2691 non-null int64
# cause_code                            2687 non-null float64
# focal_depth                           926 non-null float64
# primary_magnitude                     1520 non-null float64
# country                               2690 non-null object
# state                                 306 non-null object
# location_name                         2680 non-null object
# latitude                              2323 non-null float64
# longitude                             2322 non-null float64
# ...

# %%
df.describe()
# Out:
#                 id         year        month          day  event_validity  \
# count  2691.000000  2691.000000  2543.000000  2436.000000     2691.000000
# mean   2276.750650  1812.789669     6.627605    15.667077        2.367521
# std    1670.276286   345.423189     3.468320     8.678539        1.550095
# min       1.000000 -2000.000000     1.000000     1.000000       -1.000000
# 25%     971.500000  1822.000000     4.000000     8.000000        1.000000
# 50%    1864.000000  1899.000000     7.000000    16.000000        2.000000
# 75%    3326.500000  1961.000000    10.000000    23.000000        4.000000
# max    5753.000000  2020.000000    12.000000    31.000000        4.000000
#
#         cause_code  focal_depth  primary_magnitude     latitude    longitude  \
# count  2687.000000   926.000000        1520.000000  2323.000000  2322.000000
# mean      1.847413    36.125270           7.035000    17.162975    39.982406
# ...

# %%
df.dtypes
# Out:
# id                                      int64
# year                                    int64
# month                                 float64
# day                                   float64
# timestamp                              object
# event_validity                          int64
# cause_code                            float64
# focal_depth                           float64
# primary_magnitude                     float64
# country                                object
# state                                  object
# location_name                          object
# latitude                              float64
# longitude                             float64
# region_code                           float64
# maximum_water_height                  float64
# abe                                   float64
# iida                                  float64
# soloviev                              float64
# warning_status                        float64
# ...

# %%
df.hist(figsize=(20,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001EEB7CDA9E8>,
# ...
#       dtype=object)
